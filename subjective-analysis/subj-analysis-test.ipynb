# %% [markdown]
# # Testar lite analys

# %%
import pandas as pd
from io import StringIO
import matplotlib.pyplot as plt
import numpy as np

with open("results (15).csv") as f:
  csv_string = f.read()

# Split the two tables
table1_str = csv_string[:csv_string.find("imageA")]
table2_str = csv_string[csv_string.find("imageA"):]

table1 = pd.read_table(StringIO(table1_str), sep=",")
table2 = pd.read_table(StringIO(table2_str), sep=",")

# %%
table1
# Out:
#                           participantId surveyCode      time  age gender  \
# 0  312a7c52-7a84-44a4-9472-fc147fb0d211  lKVzlebLc  1432.307    1   male
# 1  55adec2e-2835-4aa9-aefe-b2c6b32dca1c  _fgvUTLo8   330.802   47   male
# 2  dd6e52d4-8d27-4961-94b0-27e679e0cb97  R_kaVHnYW   168.833   23   male
# 3  2769aaec-2042-479a-9e9d-2100dca259cf  glqfJFHkZ    19.183    1  other
# 4  bd3a8d7f-7bfc-441f-b0d7-709b0e33c368  bQWETiEiY   478.702   56   male
#
#   imageExperience  1648475242929\bus_bicubic.png  \
# 0    professional                              3
# 1    professional                              1
# 2       education                              2
# 3            none                              3
# 4    professional                              2
#
#    1648475242929\bus_bilinear.png  1648475242929\bus_lanczos3.png  \
# 0                               1                               0
# 1                               3                               0
# ...

# %%
table2
# Out:
#                                    imageA  \
# 0           1648475242929\bus_bicubic.png
# 1           1648475242929\bus_bicubic.png
# 2         1648475242929\bus_ogniewski.png
# 3          1648475242929\bus_bilinear.png
# 4         1648475242929\bus_ogniewski.png
# ..                                    ...
# 142   1648475242929\stonewall_bicubic.png
# 143  1648475242929\stonewall_bilinear.png
# 144  1648475242929\stonewall_bilinear.png
# 145  1648475242929\stonewall_lanczos3.png
# 146  1648475242929\stonewall_bilinear.png
#
#                                     imageB  \
# 0           1648475242929\bus_bilinear.png
# 1          1648475242929\bus_ogniewski.png
# 2           1648475242929\bus_bilinear.png
# 3          1648475242929\bus_ogniewski.png
# 4           1648475242929\bus_lanczos3.png
# ..                                     ...
# 142   1648475242929\stonewall_bilinear.png
# 143    1648475242929\stonewall_bicubic.png
# 144  1648475242929\stonewall_ogniewski.png
# ...

# %%
table1.drop('surveyCode',1,inplace=True)
table1.head(n=3)
# Out:
# /var/folders/d7/zw_ps6tx5sj0yr72q812pj180000gn/T/ipykernel_12100/3211291551.py:1: FutureWarning: In a future version of pandas all arguments of DataFrame.drop except for the argument 'labels' will be keyword-only.
#   table1.drop('surveyCode',1,inplace=True)
#                           participantId      time  age gender imageExperience  \
# 0  312a7c52-7a84-44a4-9472-fc147fb0d211  1432.307    1   male    professional
# 1  55adec2e-2835-4aa9-aefe-b2c6b32dca1c   330.802   47   male    professional
# 2  dd6e52d4-8d27-4961-94b0-27e679e0cb97   168.833   23   male       education
#
#    1648475242929\bus_bicubic.png  1648475242929\bus_bilinear.png  \
# 0                              3                               1
# 1                              1                               3
# 2                              2                               1
#
#    1648475242929\bus_lanczos3.png  1648475242929\bus_ogniewski.png  \
# 0                               0                                2
# ...

# %%
imageRes = table1.iloc[:,5:]
imageRes.head(n=3)
# Out:
#    1648475242929\bus_bicubic.png  1648475242929\bus_bilinear.png  \
# 0                              3                               1
# 1                              1                               3
# 2                              2                               1
#
#    1648475242929\bus_lanczos3.png  1648475242929\bus_ogniewski.png  \
# 0                               0                                2
# 1                               0                                2
# 2                               0                                3
#
#    1648475242929\interpsmolking_bicubic.png  \
# 0                                         3
# 1                                         1
# 2                                         1
#
#    1648475242929\interpsmolking_bilinear.png  \
# 0                                          1
# 1                                          2
# 2                                          2
#
#    1648475242929\interpsmolking_lanczos3.png  \
# ...

# %%
imageSum = imageRes.sum(axis = 0, skipna=True)
imageSum
# Out:
# 1648475242929\bus_bicubic.png                 11
# 1648475242929\bus_bilinear.png                 8
# 1648475242929\bus_lanczos3.png                 0
# 1648475242929\bus_ogniewski.png               11
# 1648475242929\interpsmolking_bicubic.png       8
# 1648475242929\interpsmolking_bilinear.png      8
# 1648475242929\interpsmolking_lanczos3.png      1
# 1648475242929\interpsmolking_ogniewski.png    12
# 1648475242929\mushroom_bicubic.png             8
# 1648475242929\mushroom_bilinear.png            3
# 1648475242929\mushroom_lanczos3.png            5
# 1648475242929\mushroom_ogniewski.png          12
# 1648475242929\smolking_lab.png                 6
# 1648475242929\smolking_linrgb.png              2
# 1648475242929\smolking_srgb.png                9
# 1648475242929\snail_lab.png                    5
# 1648475242929\snail_linrgb.png                 5
# 1648475242929\snail_srgb.png                   6
# 1648475242929\stonewall_bicubic.png            8
# ...

# %%
interp_bus = imageSum.iloc[0:4]
interp_king = imageSum.iloc[4:8]
interp_mushroom = imageSum.iloc[8:12]
color_king = imageSum.iloc[12:15]
color_snail = imageSum.iloc[15:18]
interp_stone = imageSum.iloc[18:22]

# %%
#imageSum.plot.bar()
#interp_bus.plot.bar()
# Out:
# 1648475242929\bus_bicubic.png               11
# 1648475242929\interpsmolking_bicubic.png     8
# 1648475242929\mushroom_bicubic.png           8
# 1648475242929\smolking_lab.png               6
# 1648475242929\snail_linrgb.png               5
# 1648475242929\stonewall_lanczos3.png         7
# dtype: int64

# %%
interp_data = [interp_bus,interp_king,interp_mushroom,interp_stone]
bicubic = []
bilinear = []
lanczos3 = []
ogniewski = []

for x in interp_data:
    bicubic.append(x[0])
    bilinear.append(x[1])
    lanczos3.append(x[2])
    ogniewski.append(x[3])

# %%
X = np.arange(4)
fig = plt.figure()
ax = fig.add_axes([0,0,1,1])
xaxis = ['bus','king','mushroom','stone']
xi = list(range(len(x)))
plt.xticks(xi,xaxis)


ax.bar(X - 0.3, bilinear, color = 'b', width = 0.2, align='center', label='bilinear')
ax.bar(X - 0.10, bicubic, color = 'g', width = 0.2, align='center', label='bicubic')
ax.bar(X + 0.1, lanczos3, color = 'r', width = 0.2, align='center', label='lanczos3')
ax.bar(X + 0.3, ogniewski, color = 'y', width = 0.2, align='center', label='Ogniewski')
ax.legend(loc='upper right')
